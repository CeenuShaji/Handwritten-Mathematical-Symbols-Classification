# %%
# %matplotlib inline
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from torch.utils.data import DataLoader, TensorDataset, Subset, Dataset
from sklearn.model_selection import train_test_split, KFold
from PIL import Image
import shutil
import pandas
from torchvision.io import read_image

cudnn.benchmark = True
plt.ion()   # interactive mode
#https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html

# %%
def test_model(model, dataset, labels):
    since = time.time()

    # Each epoch has a training and validation phase
    #model.eval()

    running_corrects = 0

    # Iterate over data.
    for idx in range(len(labels)):
        
        image = Image.fromarray(dataset[:, :, idx], mode = 'L').resize((320, 320))
        label = labels[idx]
        if len(label) == 1:
            label = [label]
        # zero the parameter gradients
        #optimizer.zero_grad()

        # forward
        output = model(image, size=320)
        predictions = output.pandas().xyxy[0].sort_values('xmin').loc[:, "class"].tolist()
        predictions_char_arr = [str(prediction) if prediction != 10 else 'u' for prediction in predictions]
        predictions_str = "".join(predictions_char_arr)
        print("Number of predictions: ", len(predictions_str), "Prediction: ", predictions_str)
        running_corrects += (predictions == label)
        #output.print()
        #_, preds = torch.max(outputs, 1)
        #print(preds)
        #loss = criterion(output, label)

        # statistics
        #running_loss += loss.item() * inputs.size(0)
        #running_corrects += torch.sum(preds == labels.data)

    #loss = running_loss / dataset_test_size
    acc = running_corrects / len(labels)

    print(f'Acc: {acc:.4f}')

    time_elapsed = time.time() - since
    print(f'Testing complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')

    return model

# %%
preceding_path = ""
dataset = np.load(os.path.join(preceding_path, 'data_train.npy')).reshape((300, 300, 9032))
labels = np.load(os.path.join(preceding_path, 't_train_corrected.npy'))
model_ft = torch.hub.load('ultralytics/yolov5', 'custom', path='best.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\justin.rossiter/.cache\torch\hub\master.zip
# requirements: YOLOv5 requirements "gitpython" "tqdm>=4.64.0" not found, attempting AutoUpdate...
# requirements:  Command 'pip install "gitpython" "tqdm>=4.64.0"  ' returned non-zero exit status 1.
# YOLOv5  2022-11-30 Python-3.8.8 torch-1.9.0+cu111 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7039792 parameters, 0 gradients
# Adding AutoShape...

# %%
test_model(model_ft, dataset, labels)
# Out:
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 7.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 6.1ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 0.0ms pre-process, 6.1ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  1
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 7.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 7.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 0.0ms pre-process, 6.1ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  8
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 6.1ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 1.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 0.0ms pre-process, 6.1ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  9
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 6.1ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 0.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  0
# image 1/1: 320x320 1 plus sign
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 5.1ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  5
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 5.1ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  8
# image 1/1: 320x320 1 square root
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 0.0ms pre-process, 7.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 0.0ms pre-process, 6.1ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  8
# image 1/1: 320x320 1 summation
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 5.1ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 0.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 other
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  u
# Number of predictions:  1 Prediction:  3
# image 1/1: 320x320 1 summation
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  3
# image 1/1: 320x320 1 partial
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 5.1ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  9
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  7
# image 1/1: 320x320 1 summation
# Speed: 1.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 1.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  8
# image 1/1: 320x320 1 product
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 0.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 0.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  0
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 1.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  2
# image 1/1: 320x320 1 pi
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 0.0ms pre-process, 6.1ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  1
# image 1/1: 320x320 1 product
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 0.0ms pre-process, 7.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  2
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 0.0ms pre-process, 7.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 7.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  8
# image 1/1: 320x320 1 product
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  5
# image 1/1: 320x320 1 summation
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 0.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 0.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  5
# image 1/1: 320x320 1 plus sign
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  2
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# ...
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  7
# image 1/1: 320x320 1 summation
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 7.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 1.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product, 1 pi
# Speed: 1.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 1.0ms pre-process, 7.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 0.0ms pre-process, 7.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 7.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 1.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 0.0ms pre-process, 7.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  2
# Number of predictions:  2 Prediction:  78
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  7
# image 1/1: 320x320 1 product
# Speed: 0.0ms pre-process, 7.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 0.0ms pre-process, 7.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  5
# image 1/1: 320x320 1 pi
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 1.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 (no detections)
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 0.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product, 1 pi
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  0
# Number of predictions:  0 Prediction:
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  0
# Number of predictions:  2 Prediction:  87
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 0.0ms pre-process, 7.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  7
# image 1/1: 320x320 1 negative sign
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 pi
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 0.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 summation
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 square root
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 percent
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  8
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  9
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  1
# Number of predictions:  1 Prediction:  5
# Number of predictions:  1 Prediction:  6
# image 1/1: 320x320 1 plus sign
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 equal
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 plus sign
# Speed: 1.0ms pre-process, 5.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 x
# Speed: 1.0ms pre-process, 5.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 0.0ms pre-process, 7.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 negative sign
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 partial
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 0.0ms pre-process, 6.0ms inference, 2.0ms NMS per image at shape (1, 3, 320, 320)
# image 1/1: 320x320 1 product
# Speed: 0.0ms pre-process, 7.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  4
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  2
# Number of predictions:  1 Prediction:  0
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  3
# Number of predictions:  1 Prediction:  6
# Number of predictions:  1 Prediction:  7
# image 1/1: 320x320 1 product
# Speed: 1.0ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# Number of predictions:  1 Prediction:  7
# Number of predictions:  1 Prediction:  7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-2c044d0d3129> in <module>
# ----> 1 test_model(model_ft, dataset, labels)
#
# <ipython-input-20-c5b0ec1213cf> in test_model(model, dataset, labels)
#      16
#      17         # forward
# ---> 18         output = model(image, size=320)
#      19         output.print()
#      20         predictions = output.pandas().xyxy[0].sort_values('xmin').loc[:, "class"].tolist()
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# ~/.cache\torch\hub\ultralytics_yolov5_master\models\common.py in forward(self, ims, size, augment, profile)
#     715                                         max_det=self.max_det)  # NMS
#     716                 for i in range(n):
# --> 717                     scale_boxes(shape1, y[i][:, :4], shape0[i])
#     718
#     719             return Detections(ims, y, files, dt, self.names, x.shape)
#
# ~/.cache\torch\hub\ultralytics_yolov5_master\utils\general.py in scale_boxes(img1_shape, boxes, img0_shape, ratio_pad)
#     834         pad = ratio_pad[1]
#     835
# --> 836     boxes[:, [0, 2]] -= pad[0]  # x padding
#     837     boxes[:, [1, 3]] -= pad[1]  # y padding
#     838     boxes[:, :4] /= gain
#
# KeyboardInterrupt:
